# %%
import optuna

from prj.config import EXP_DIR

# Define the source and destination storage URIs
source_storage = optuna.storages.RDBStorage('sqlite:///' + str(EXP_DIR / 'tuning' / 'lgbm_20241128_140415' / 'optuna_study.db'))
destination_storage = optuna.storages.RDBStorage("mysql+pymysql://admin:F1g5w#6zP4TN@janestreet.c3uaekuseqse.us-east-1.rds.amazonaws.com/janestreet")  # Remote MySQL database


study_summaries = optuna.get_all_study_summaries(storage=source_storage)
study_name = [summary.study_name for summary in study_summaries][0]

print('Found study: ', study_name)

optuna.copy_study(from_storage=source_storage, to_storage=destination_storage, from_study_name=study_name)

print(f"Study '{study_name}' has been copied to the remote storage.")
# Out:
# Found study:  LGBMRegressor_1seeds_7_8-9_9
# [I 2024-11-29 14:31:11,828] A new study created in RDB with name: LGBMRegressor_1seeds_7_8-9_9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      11 study_name = [summary.study_name for summary in study_summaries][0]
#      13 print('Found study: ', study_name)
# ---> 15 optuna.copy_study(from_storage=source_storage, to_storage=destination_storage, from_study_name=study_name)
#      17 print(f"Study '{study_name}' has been copied to the remote storage.")
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/_convert_positional_args.py:83, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#      77     raise TypeError(
#      78         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#      79     )
#      81 kwargs.update(inferred_kwargs)
# ---> 83 return func(**kwargs)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/study/study.py:1531, in copy_study(from_study_name, from_storage, to_storage, to_study_name)
#    1528     to_study.set_user_attr(key, value)
#    1530 # Trials are deep copied on `add_trials`.
# -> 1531 to_study.add_trials(from_study.get_trials(deepcopy=False))
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/study/study.py:1004, in Study.add_trials(self, trials)
#     967 """Add trials to study.
#     968
#     969 The trials are validated before being added.
#    (...)
#    1000
#    1001 """
#    1003 for trial in trials:
# -> 1004     self.add_trial(trial)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/study/study.py:964, in Study.add_trial(self, trial)
#     957 if trial.values is not None and len(self.directions) != len(trial.values):
#     958     raise ValueError(
#     959         f"The added trial has {len(trial.values)} values, which is different from the "
#     960         f"number of objectives {len(self.directions)} in the study (determined by "
#     961         "Study.directions)."
#     962     )
# --> 964 self._storage.create_new_trial(self._study_id, template_trial=trial)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:149, in _CachedStorage.create_new_trial(self, study_id, template_trial)
#     148 def create_new_trial(self, study_id: int, template_trial: FrozenTrial | None = None) -> int:
# --> 149     frozen_trial = self._backend._create_new_trial(study_id, template_trial)
#     150     trial_id = frozen_trial._trial_id
#     151     with self._lock:
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:486, in RDBStorage._create_new_trial(self, study_id, template_trial)
#     482     with _create_scoped_session(self.scoped_session) as session:
#     483         # This lock is necessary because the trial creation is not an atomic operation
#     484         # and the calculation of trial.number is prone to race conditions.
#     485         models.StudyModel.find_or_raise_by_id(study_id, session, for_update=True)
# --> 486         trial = self._get_prepared_new_trial(study_id, template_trial, session)
#     487         return _create_frozen_trial(trial, template_trial)
#     488 # sqlalchemy_exc.OperationalError is converted to ``StorageInternalError``.
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:551, in RDBStorage._get_prepared_new_trial(self, study_id, template_trial, session)
#     549     distribution = template_trial.distributions[param_name]
#     550     param_value_in_internal_repr = distribution.to_internal_repr(param_value)
# --> 551     self._set_trial_param_without_commit(
#     552         session, trial.trial_id, param_name, param_value_in_internal_repr, distribution
#     553     )
#     555 for key, value in template_trial.user_attrs.items():
#     556     self._set_trial_attr_without_commit(
#     557         session, models.TrialUserAttributeModel, trial.trial_id, key, value
#     558     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:597, in RDBStorage._set_trial_param_without_commit(self, session, trial_id, param_name, param_value_internal, distribution)
#     589 def _set_trial_param_without_commit(
#     590     self,
#     591     session: "sqlalchemy_orm.Session",
#    (...)
#     595     distribution: distributions.BaseDistribution,
#     596 ) -> None:
# --> 597     trial = models.TrialModel.find_or_raise_by_id(trial_id, session)
#     598     self.check_trial_is_updatable(trial_id, trial.state)
#     600     trial_param = models.TrialParamModel(
#     601         trial_id=trial_id,
#     602         param_name=param_name,
#     603         param_value=param_value_internal,
#     604         distribution_json=distributions.distribution_to_json(distribution),
#     605     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/optuna/storages/_rdb/models.py:250, in TrialModel.find_or_raise_by_id(cls, trial_id, session, for_update)
#     247 if for_update:
#     248     query = query.with_for_update()
# --> 250 trial = query.one_or_none()
#     251 if trial is None:
#     252     raise KeyError(NOT_FOUND_MSG)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2754, in Query.one_or_none(self)
#    2730 def one_or_none(self) -> Optional[_T]:
#    2731     """Return at most one result or raise an exception.
#    2732
#    2733     Returns ``None`` if the query selects
#    (...)
#    2752
#    2753     """
# -> 2754     return self._iter().one_or_none()
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2827, in Query._iter(self)
#    2824 params = self._params
#    2826 statement = self._statement_20()
# -> 2827 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2828     statement,
#    2829     params,
#    2830     execution_options={"_sa_orm_load_options": self.load_options},
#    2831 )
#    2833 # legacy: automatically set scalars, unique
#    2834 if result._attributes.get("is_single_entity", False):
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2362, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2301 def execute(
#    2302     self,
#    2303     statement: Executable,
#    (...)
#    2309     _add_event: Optional[Any] = None,
#    2310 ) -> Result[Any]:
#    2311     r"""Execute a SQL expression construct.
#    2312
#    2313     Returns a :class:`_engine.Result` object representing
#    (...)
#    2360
#    2361     """
# -> 2362     return self._execute_internal(
#    2363         statement,
#    2364         params,
#    2365         execution_options=execution_options,
#    2366         bind_arguments=bind_arguments,
#    2367         _parent_execute_state=_parent_execute_state,
#    2368         _add_event=_add_event,
#    2369     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2226, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2215     execution_options = orm_exec_state.local_execution_options
#    2217 if compile_state_cls is not None:
#    2218     # now run orm_pre_session_exec() "for real".   if there were
#    2219     # event hooks, this will re-run the steps that interpret
#    2220     # new execution_options into load_options / update_delete_options,
#    2221     # which we assume the event hook might have updated.
#    2222     # autoflush will also be invoked in this step if enabled.
#    2223     (
#    2224         statement,
#    2225         execution_options,
# -> 2226     ) = compile_state_cls.orm_pre_session_exec(
#    2227         self,
#    2228         statement,
#    2229         params,
#    2230         execution_options,
#    2231         bind_arguments,
#    2232         False,
#    2233     )
#    2235 bind = self.get_bind(**bind_arguments)
#    2237 conn = self._connection_for_bind(bind)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/context.py:561, in ORMCompileState.orm_pre_session_exec(cls, session, statement, params, execution_options, bind_arguments, is_pre_event)
#     558         bind_arguments["mapper"] = plugin_subject.mapper
#     560 if not is_pre_event and load_options._autoflush:
# --> 561     session._autoflush()
#     563 return statement, execution_options
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:3050, in Session._autoflush(self)
#    3048 if self.autoflush and not self._flushing:
#    3049     try:
# -> 3050         self.flush()
#    3051     except sa_exc.StatementError as e:
#    3052         # note we are reraising StatementError as opposed to
#    3053         # raising FlushError with "chaining" to remain compatible
#    3054         # with code that catches StatementError, IntegrityError,
#    3055         # etc.
#    3056         e.add_detail(
#    3057             "raised as a result of Query-invoked autoflush; "
#    3058             "consider using a session.no_autoflush block if this "
#    3059             "flush is occurring prematurely"
#    3060         )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4352, in Session.flush(self, objects)
#    4350 try:
#    4351     self._flushing = True
# -> 4352     self._flush(objects)
#    4353 finally:
#    4354     self._flushing = False
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4487, in Session._flush(self, objects)
#    4484     transaction.commit()
#    4486 except:
# -> 4487     with util.safe_reraise():
#    4488         transaction.rollback(_capture_exception=True)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4448, in Session._flush(self, objects)
#    4446 self._warn_on_events = True
#    4447 try:
# -> 4448     flush_context.execute()
#    4449 finally:
#    4450     self._warn_on_events = False
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/connections.py:744, in Connection._read_packet(self, packet_type)
#     742 buff = bytearray()
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#     747     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~/Desktop/Projects/jane_street_forecasting/.venv/lib/python3.10/site-packages/pymysql/connections.py:782, in Connection._read_bytes(self, num_bytes)
#     780 while True:
#     781     try:
# --> 782         data = self._rfile.read(num_bytes)
#     783         break
#     784     except OSError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
destination_storage = optuna.storages.RDBStorage("mysql+pymysql://admin:F1g5w#6zP4TN@janestreet.c3uaekuseqse.us-east-1.rds.amazonaws.com/janestreet")
study_summaries = optuna.get_all_study_summaries(storage=source_storage)
study_names = [summary.study_name for summary in study_summaries]
study_names
# Out:
# ['LGBMRegressor_1seeds_7_8-9_9']
